# %% [markdown]
# # Efficient Yelp API Calls (Core)

# %% [markdown]
# ## Imports

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ## Load API Credentials

# %%
# Load API Credentials
with open('/Users/dmburns/.secret/yelp_api.json') as f:   #use your path here!
    login = json.load(f)
# Instantiate YelpAPI Variable
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %% [markdown]
# ## Create json file function

# %%
def create_json_file(JSON_FILE,  delete_if_exists=False):
    
    ## Check if JSON_FILE exists
    file_exists = os.path.isfile(JSON_FILE)
    
    ## If it DOES exist:
    if file_exists == True:
        
        ## Check if user wants to delete if exists
        if delete_if_exists==True:
            
            print(f"[!] {JSON_FILE} already exists. Deleting previous file...")
            ## delete file and confirm it no longer exits.
            os.remove(JSON_FILE)
            ## Recursive call to function after old file deleted
            create_json_file(JSON_FILE,delete_if_exists=False)
        else:
            print(f"[i] {JSON_FILE} already exists.")            
            
            
    ## If it does NOT exist:
    else:
        
        ## INFORM USER AND SAVE EMPTY LIST
        print(f"[i] {JSON_FILE} not found. Saving empty list to new file.")
        
        ## CREATE ANY NEEDED FOLDERS
        # Get the Folder Name only
        folder = os.path.dirname(JSON_FILE)
        
        ## If JSON_FILE included a folder:
        if len(folder)>0:
            # create the folder
            os.makedirs(folder,exist_ok=True)
        ## Save empty list to start the json file
        with open(JSON_FILE,'w') as f:
            json.dump([],f)

# %% [markdown]
# ## Define Parameters of Search

# %%
# set our API call parameters 
LOCATION = 'Culver City, CA'
TERM = 'Irish Pub'

# %%
# Specifying JSON_FILE filename (can include a folder)
# include the search terms in the filename
JSON_FILE = "Data/results_in_progress_NY_pizza.json"
JSON_FILE
# Out:
# 'Data/results_in_progress_NY_pizza.json'

# %%
## Create a new empty json file (exist the previous if it exists)
create_json_file(JSON_FILE, delete_if_exists=True)
## Load previous results and use len of results for offset
with open(JSON_FILE,'r') as f:
    previous_results = json.load(f)
    
## set offset based on previous results
n_results = len(previous_results)
print(f'- {n_results} previous results found.')
# use our yelp_api variable's search_query method to perform our API call
results = yelp_api.search_query(location=LOCATION,
                                term=TERM,
                               offset=n_results)
## How many results total?
total_results = results['total']
## How many did we get the details for?
results_per_page = len(results['businesses'])
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total']-n_results)/ results_per_page)
n_pages
# Out:
# [!] Data/results_in_progress_NY_pizza.json already exists. Deleting previous file...
# [i] Data/results_in_progress_NY_pizza.json not found. Saving empty list to new file.
# - 0 previous results found.
# 11

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    
    if (n_results + results_per_page) > 1000:
        print('Exceeded 1000 api calls. Stopping loop.')
        break
    
    ## use n_results as the OFFSET 
    results = yelp_api.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    # display(previous_results)
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
    
    time.sleep(.2)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
# load final results
final_df = pd.read_json(JSON_FILE)
display(final_df.head(), final_df.tail())
# Out:
#                        id                                             alias  \
# 0  4fudS9qKOASO9iY2MA5OMg                        the-auld-fella-culver-city
# 1  hiJlbuDfwHtRskZnaOvcxw  the-irish-times-pub-and-restaurant-los-angeles-2
# 2  no0VF_8JR_g3uR1wiQFmMA                           joxer-dalys-culver-city
# 3  f1GPDSXDplLlyvXxDTsdyg  o-briens-irish-pub-and-restaurant-santa-monica-2
# 4  PjScb-Rj3wFcOEaFNRKxdA                           tom-bergins-los-angeles
#
#                                name  \
# 0                    The Auld Fella
# 1  The Irish Times Pub & Restaurant
# 2                      Joxer Daly's
# 3   O'Briens Irish Pub & Restaurant
# 4                      Tom Bergin's
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/eBjipq...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/MbS3uI...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/8d7b-r...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/ny0_oR...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/M9CiUt...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-auld-fella-culver...           241
# 1  https://www.yelp.com/biz/the-irish-times-pub-a...           268
# 2  https://www.yelp.com/biz/joxer-dalys-culver-ci...           442
# 3  https://www.yelp.com/biz/o-briens-irish-pub-an...           393
# 4  https://www.yelp.com/biz/tom-bergins-los-angel...           542
#
#                                           categories  rating  \
# 0    [{'alias': 'irish_pubs', 'title': 'Irish Pub'}]     4.0
# 1  [{'alias': 'irish', 'title': 'Irish'}, {'alias...     4.0
# 2  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     3.5
# 3  [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 4  [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 34.0246794496627, 'longitude': -1...  [delivery, pickup]
# 1     {'latitude': 34.02955, 'longitude': -118.4114}  [delivery, pickup]
# 2  {'latitude': 34.0077399, 'longitude': -118.412...                  []
# 3  {'latitude': 34.0331641, 'longitude': -118.480...  [delivery, pickup]
# 4     {'latitude': 34.06007, 'longitude': -118.3625}          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '9375 Culver Blvd', 'address2': '...  +14243615100
# 1    $$  {'address1': '3267 Motor Ave', 'address2': '',...  +13105599648
# 2    $$  {'address1': '11168 Washington Blvd', 'address...  +13108383745
# 3    $$  {'address1': '2226 Wilshire Blvd', 'address2':...  +13108295303
# 4    $$  {'address1': '840 S Fairfax Ave', 'address2': ...  +13239367151
#
#     display_phone     distance
# 0  (424) 361-5100  2486.503530
# 1  (310) 559-9648  2635.568207
# 2  (310) 838-3745   373.384477
# 3  (310) 829-5303  7267.667956
# 4  (323) 936-7151  7369.533312
#                          id                                    alias  \
# 199  IECg-CbB39J08ITsDD9LXA         largo-at-the-coronet-los-angeles
# 200  Y9-Y9sy9Ss8lrICt6cp29Q  coast-beach-cafe-and-bar-santa-monica-3
# 201  zGnuW3tpp5bjojA6XMxeEw                    red-lobster-inglewood
# 202  gol97typwuGAaRvklK5viA    the-cheesecake-factory-los-angeles-12
# 203  HVph9K78qaFPiG0zveOZjA                      coles-los-angeles-4
#
#                          name  \
# 199      Largo at the Coronet
# 200  Coast Beach Cafe and Bar
# 201               Red Lobster
# 202    The Cheesecake Factory
# 203                    Cole's
#
#                                              image_url  is_closed  \
# 199  https://s3-media1.fl.yelpcdn.com/bphoto/38DXaH...      False
# 200  https://s3-media3.fl.yelpcdn.com/bphoto/PPqig1...      False
# 201  https://s3-media3.fl.yelpcdn.com/bphoto/3OiONT...      False
# 202  https://s3-media1.fl.yelpcdn.com/bphoto/aWlJTz...      False
# 203  https://s3-media4.fl.yelpcdn.com/bphoto/DM_5qI...      False
#
#                                                    url  review_count  \
# 199  https://www.yelp.com/biz/largo-at-the-coronet-...           372
# 200  https://www.yelp.com/biz/coast-beach-cafe-and-...           426
# 201  https://www.yelp.com/biz/red-lobster-inglewood...           672
# 202  https://www.yelp.com/biz/the-cheesecake-factor...          1782
# 203  https://www.yelp.com/biz/coles-los-angeles-4?a...           155
#
#                                             categories  rating  \
# 199  [{'alias': 'musicvenues', 'title': 'Music Venu...     4.0
# 200  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     3.5
# 201  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     2.5
# 202  [{'alias': 'desserts', 'title': 'Desserts'}, {...     3.0
# 203  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     2.0
#
#                                            coordinates        transactions  \
# 199     {'latitude': 34.07795, 'longitude': -118.3762}                  []
# 200  {'latitude': 34.0067348396701, 'longitude': -1...          [delivery]
# 201  {'latitude': 33.9451776, 'longitude': -118.331...  [delivery, pickup]
# 202  {'latitude': 34.07198098183971, 'longitude': -...                  []
# 203  {'latitude': 33.9406375662965, 'longitude': -1...                  []
#
#     price                                           location         phone  \
# 199    $$  {'address1': '366 N La Cienega Blvd', 'address...  +13108550350
# 200   $$$  {'address1': '1 Pico Blvd', 'address2': None, ...  +13105871707
# 201    $$  {'address1': '3400 W Century Blvd', 'address2'...  +13106778430
# 202    $$  {'address1': '189 The Grove Dr', 'address2': '...  +13236340511
# 203    $$  {'address1': '400 World Way', 'address2': '', ...
#
#       display_phone     distance
# 199  (310) 855-0350  8537.602024
# 200  (310) 587-1707  7647.093110
# 201  (310) 677-8430  9851.248353
# 202  (323) 634-0511  8711.858142
# 203                  7268.977350

# %%
type(final_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# check for duplicate ID's 
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
## Drop duplicate ids and confirm there are no more duplicates
final_df = final_df.drop_duplicates(subset='id')
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
# save the final results to a compressed csv
final_df.to_csv('Data/final_results_NY_pizza.csv.gz', compression='gzip',index=False)
